# %% [markdown]
# ## Basics of Neural ODEs or How I Learned the Velocity of a Falling Object
#
# If you recall from your introductory physics class, the velocity of a falling ball at some time with quadratic drag is given by,
#
# $$ \frac{dv}{dt} = \theta_1 - \theta_2 v^{2} $$
#
# This is simply Newton's law stating that the change in velocity with respect to time is given by the gravitational constant $\theta_1$ (which works to speed up the ball) minus some drag coefficient $\theta_2$ times the square of the velocity (which works to reduce the speed of the ball when it's going fast).
#
# First, let's implement the forward model.  Below, you will need to code just the right hand side of the equation above.

# %%
from scipy.integrate import odeint #This will solve our ODEs
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

def dvdt(v, t, thetas): # velocity of the falling baseball from newton
    ### TODO implement the dynamics function provided above given a list of thetas
    ### Hint: The t argument is just present to make the ode solver happy. It is not actually used in the function.
    gravity, drag = thetas
    acceleration = gravity - drag * v ** 2
    return acceleration

# %% [markdown]
# Now that we have a function that describes how $v$ changes through time, we can use the scipy package odeint to perform numerical integration through time and produce an approximate numerical solution.

# %%
times = np.linspace(0, 3, 50) # These are the times at which we would like to output our solution 
true_thetas = [10, 0.2] # These are the parameters that we will take to be "true".  Later, we will try to recover them
initial_velocity = 0 #The initial condition of our velocity

out = odeint(dvdt, initial_velocity, times, (true_thetas,)) #Integrate our dynamics function outputting at each time
v_true = out[:,0]

plt.figure(figsize =(10,7))
plt.plot(times, v_true, '-', label = 'Data') #plot the data and the inital guess
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('True Ball Velocity')
plt.legend()

# %% [markdown]
# Now let's imagine that we didn't know the true parameters, but wanted to recover them from data.  We can simulate some noisy data as follows:

# %%
# Add some noise to give us our true 'observations'
v_train = v_true + np.random.randn(v_true.size)*0.5

plt.figure(figsize =(10,7))
plt.plot(times, v_train, '.', label = 'Data') #plot the data and the inital guess
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Ball Velocity Data')
plt.legend()

# %% [markdown]
# Let's take a wrong guess as to what our parameters might be, and see how well we predict the data:

# %%
# Now, let's pretend like we don't know the true values of our thetas.
guess_thetas = gravity, drag = 10, 0.2 #Make an inital guess as to what the parameters might be.

### This is for plotting later
meshv = np.linspace(0, 9, 27) # 27 becomes the number of columns in the meshgrid
mesht = np.linspace(0, 3, 12) # 12 becomes the number of rows
meshv, mesht = np.meshgrid(meshv,mesht) # Two matrices
changet = np.ones(meshv.shape)*5 # A matrix shaped (12, 27)

out = odeint(dvdt, initial_velocity, times, (guess_thetas,))
v_guess = out[:,0]

plt.figure(figsize =(10,7))
plt.plot(times, v_train, '.', label = 'Data') #plot the data and the inital guess
plt.plot(times, v_guess, '--', label = 'Guess')
plt.xlabel('Time (s)')
plt.ylabel('Velocity (m/s)')
plt.title('Ball Velocity Data')
plt.legend()

# %% [markdown]
# Maybe your guess is good, but maybe it's not.  As always in ML, we need to train our parameters by minimizing a loss function.  For our purposes, the loss will be sum squared error:
# $$ L = \sum_{t_i \in t_{obs}} \frac{1}{2} \left( v(t_i) - v_{obs,i}\right)^2.$$
#
# We would like to use the adjoint method to compute the gradient of this cost function with respect to the parameters $\theta_0$ and $\theta_1$.  To begin, we will need to derive the continuous analog of the chain rule, namely the adjoint, which gives us $a(t) = \frac{\partial L}{\partial v}$ at any point in time.  Equation 4from Chen provides us with the adjoint equation, which is another ODE that we can solve:
# $$ \frac{\partial a}{\partial t} = -a(t) \frac{\partial f(v,t,\theta)}{\partial v}, $$ where $f(v,t,\theta)$ is the right hand side of the ODE.
#
# ### Question 1: Show that
# $$ \frac{\partial f(v,t,\theta)}{\partial v(t)} = -2 \theta_1 v(t) $$
#
# Note that this equation depends on $v(t)$!  Thus we either have to store $v(t)$ from the forward pass (which is equivalent to reverse mode AD), or we have to solve the equation for $v(t)$ backwards in time along with the adjoint equation, which is what we do here.
#
# If we had a continuous cost function, the adjoint equation would also have a source term.  However, because our observations are discrete, we have a discontinous jump in the value of the adjoint at every observation.  The natural way of handling this discontinuity is to solve the adjoint equation backwards in time over every interval between observations, with initial condition $a(t_i)^+$ given by
# $$
# a(t_i)^+ = a(t_i)^- + v(t_i) - v_{obs}(t_i),
# $$
#
# where $a(t_i)^{-}$ is the adjoint at $t_i$ before we see the observation.  In words, this says that we should solve the adjoint equation backwards in time until we encounter an observation.  When we encounter an observation, we add the residual between the modeled and observed velocity at that point to the adjoint (discontinuously) and then continue solving backwards in time until we get to the next observation, and so on.  This discontinuous treatment can be seen in the adjoint method below.
#
# With the adjoint in hand, we can compute the gradients of the cost with respect to the parameters $\theta_1$ and $\theta_2$ using Equation 5 from Chen.  If take the derivative of Eq. 5 with respect to time, we get another ODE for each parameter's gradient:
# $$
# \frac{\partial g_{\theta_k}}{\partial t} = -a(t) \frac{\partial f(v,t,\theta)}{\partial \theta_k},
# $$
# where $g_{\theta_k} = \frac{\partial L}{\partial \theta_k}$.  These ODEs are easy to solve by appending them to the adjoint.  Thus, for this problem the backward pass involves solving a system of four ODEs simultaneously: the adjoint equation, the forward model (but backwards in time), and an ODE for each parameter.

# %%
class FallingVelocity():
    
    def __init__(self, observations, thetas, times):
        
        self.observations = observations #our observation velocity
        self.thetas = thetas  #list of initial params must have opposite signs!
        self.times = times #our observation times
        
        
    def _dvdt(self, v, t): ### velocity of the falling baseball from newton : copied from above
        return self.thetas[0] - self.thetas[1]*v**2
    
    def _dadt(self, augmented_state, t):
        v = augmented_state[0]
        a = augmented_state[1]
        dLdtheta0 = augmented_state[2] #You won't use this
        dLdtheta1 = augmented_state[3] #You won't use this either
        
        return np.array([self.thetas[0] - self.thetas[1]*v**2,     # RHS forward model
                         -2 * self.thetas[1] * v,                                      # RHS adjoint equation
                         -a,                                       # integrand for theta_0
                         a])                                     # integrand for theta_1

    def forward(self):
        #Forward pass integration to get final velocity
        out = odeint(self._dvdt, 0, self.times)
        v_pred = out[:,0]       
        return v_pred    #all velocities are stored merely for ease of plotting purposes.

    def adjoint(self, output):
        currentvel = output #initial velocity 
        
        time_backwards = self.times[::-1] #since we are integrating backwards in time   
        observations_backward = self.observations[::-1]
        augmented_state = [np.array([currentvel,observations_backward[0]-currentvel,0,0])]
        
        for i in range(len(self.times)-1): #Solve odes between each datapoint
                       
            ## Here is where we integrate backwards through the network
            
            backward_time_range = time_backwards[i:(i+2)]
            
            ###TODO add ajoint for theta1 
            backward = odeint(self._dadt,augmented_state[-1],backward_time_range)[-1].ravel()
            augmented_state.append(np.array([backward[0],
                                             backward[1] + backward[0] - observations_backward[i+1],
                                             backward[2],
                                             backward[3]]))     
            
        return augmented_state[-1][2], augmented_state[-1][3] #??? What are we returning here?

# This is where I create times which are not evenly spaced
import random
times = [0]
for i in range(1, 50):
    times.append(times[i - 1] + random.randint(0, 10))
times = np.array(times)
times = times / max(times)
times *= 3
print(times)
    
model = FallingVelocity(v_train, [4, 1.], times)

eta = 0.0001 # Step size to take/learning rate. Breaks pretty easily, be careful here

for i in range(6500):

    output = model.forward()
    
    grad_theta0, grad_theta1 = model.adjoint(output[-1]) ### Only feed the model the final state for backward pass
    ### TODO update thetas
    model.thetas[0] -= grad_theta0 * eta
    model.thetas[1] -= grad_theta1 * eta
       
    if i % 100 == 0:
        print(grad_theta0, grad_theta1)

        clear_output(wait=True)
        plt.figure(figsize = (15, 7))
        plt.subplot(121)
        plt.plot(times, v_train, '.r', label='Observations')
        plt.plot(times, output, 'b', label='Leared Dynamics', linewidth = 2)
        plt.xlabel('Time (s)')
        plt.ylabel('Velocity (m/s)')
        plt.legend()
        plt.subplot(122)
        changev = dvdt(meshv, mesht, model.thetas)
        plt.quiver(mesht, meshv, changet, changev, width = .005)
        plt.xlabel('Time (s)')
        plt.ylabel('Velocity (m/s)')
        plt.title('Underlying Dynamics')
        plt.show()
        print('Iter {:04d}'.format(i))
# Out:
# Iter 6400

# %% [markdown]
# ### Question 2: What would happen the velocity trajectory if we only had observations of the initial and final state?
# A: The number of observations correlate positively with the accuracy of the model. The time accuracy tradeoff can be adjusted by adding and removing observations in this way.
#
# ### Question 3: Run the model again, but alter the observation data times so they are no longer evenly spaced. Does this method still work?
# A: I did not notice much difference in my predictions so long as the number of observations was the same.
#
# ## Let's find the velocity again with a neural network
# For this section, we'll use the  `torchdiffeq` package, which was created by the authors of the paper.  You can install it with `pip install torchdiffeq`
#
# Now, we can also ask the question: "what if we didn't know the right hand side of the ODE a priori?" what should we do then?  In the previous example, we explicitly knew the ODE that described the dynamics of the velocity.
#
# $$ \frac{dv}{dt} = \theta_1 + \theta_2 v^{2} $$
#
# If we don't know the ODE that describes the velocity, we can represent it with a neural network!

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchdiffeq import odeint as odeint_nn
from torchdiffeq import odeint_adjoint ## Can use this if we want to use the adjoint method

# NN that will be used to approximate dvdt 
class ODEFunc(nn.Module):

    def __init__(self):
        super(ODEFunc, self).__init__()

        self.net = nn.Sequential(
            nn.Linear(1, 50),
            nn.Tanh(),
            nn.Linear(50, 1),
        )

        for m in self.net.modules():
            if isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0, std=0.1)
                nn.init.constant_(m.bias, val=0)

    def forward(self, t, y):
        print("YYY", y)
        return self.net(y)

    
# Number of time steps to integrate forward
batch_time = 10
# Number of batch samples to use in each gradient descent step
batch_size = 10

# This is how minibatch is imiplemented in the torchdiffeq examples. Interestingly, the model can get good 
# results by only training on 10 data points at a time.
def get_batch(y, t):
    
    true_y = torch.Tensor(y)
    t = torch.Tensor(t)
    
    s = torch.from_numpy(np.random.choice(np.arange(len(t) - batch_time, dtype=np.int64), batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = t[:batch_time]  # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0, batch_t, batch_y

# %%
# changing the time spacing from uneven to even
import random
times = [0]
for i in range(1, 50):
    times.append(times[i - 1] + random.randint(0, 10))
times = np.array(times)
times = times / max(times)
times *= 3
print("Uneven", times)

times = np.linspace(0, 3, 50) # These are the times at which we would like to output our solution 
print("Even", times)
# Out:
# Uneven [0.         0.03488372 0.13953488 0.1744186  0.29069767 0.29069767
#  0.40697674 0.45348837 0.53488372 0.58139535 0.65116279 0.73255814
#  0.73255814 0.81395349 0.86046512 0.96511628 1.08139535 1.13953488
#  1.24418605 1.25581395 1.3255814  1.3255814  1.43023256 1.51162791
#  1.51162791 1.56976744 1.6744186  1.76744186 1.77906977 1.77906977
#  1.84883721 1.93023256 1.96511628 2.08139535 2.12790698 2.19767442
#  2.26744186 2.34883721 2.39534884 2.5        2.5        2.60465116
#  2.65116279 2.72093023 2.75581395 2.80232558 2.89534884 2.94186047
#  2.95348837 3.        ]
# Even [0.         0.06122449 0.12244898 0.18367347 0.24489796 0.30612245
#  0.36734694 0.42857143 0.48979592 0.55102041 0.6122449  0.67346939
#  0.73469388 0.79591837 0.85714286 0.91836735 0.97959184 1.04081633
#  1.10204082 1.16326531 1.2244898  1.28571429 1.34693878 1.40816327
#  1.46938776 1.53061224 1.59183673 1.65306122 1.71428571 1.7755102
#  1.83673469 1.89795918 1.95918367 2.02040816 2.08163265 2.14285714
#  2.20408163 2.26530612 2.32653061 2.3877551  2.44897959 2.51020408
#  2.57142857 2.63265306 2.69387755 2.75510204 2.81632653 2.87755102
#  2.93877551 3.        ]

# %%
vel_train = times
vel_train2 = vel_train[:,np.newaxis]

model = ODEFunc()
optimizer = optim.RMSprop(model.parameters(), lr=1e-3)

for itr in range(1000):
    
    optimizer.zero_grad()
    
    # Get initial state, time steps, true y values at each timestep.
    batch_y0, batch_t, batch_y = get_batch(vel_train2, times)

    # TODO: Use NODE to integrate forward
    # Hint: The odeint implemented in the torchdiffeq package uses the same syntax as the scipy odeint function.
    #       Only now, we are using a NN instead of a predefined dvdt function.
    pred_y = odeint_nn(model.forward, torch.tensor([0.0]), torch.tensor(batch_t))
    # NOTE: We are just backpropagating throught the ODE solver here. However, if we want to use the 
    #       adjoint method implemented in torchdiffeq, all we have to do is call odeint_adjoint() rather
    #       than odeint_nn(). Both functions use the same syntax.
    
    
    # loss = torch.sqrt(torch.mean((pred_y - batch_y) ** 2))
    loss = torch.mean(torch.abs(pred_y - batch_y))
    
    loss.backward()
    optimizer.step()

    if itr % 100 == 0:
        clear_output(wait=True)
        with torch.no_grad():
            plt.figure(figsize = (15, 7))
            plt.subplot(121)
            # TODO: Run model forward from time zero at all time steps so we can track progress
            pred_y = odeint_nn(model.forward, torch.tensor([0.0]), torch.tensor(vel_train2))
            loss = torch.mean(torch.abs(pred_y - torch.Tensor(vel_train2)))
            plt.plot(times, vel_train2, '.r', label='Observations')
            plt.plot(times, pred_y, 'b', label='NODE Model')
            plt.xlabel('Time (s)')
            plt.ylabel('Velocity (m/s)')
            plt.legend()
            plt.subplot(122)
            
            for i in range(4*3):
                for j in range(9*3):
                    changev = model.forward(i/3, torch.tensor([float(j/3)]))
                    plt.quiver(i/3, j/3, 5, changev, width = .005, headwidth = 3)
            plt.xlabel('Time (s)'),
            plt.ylabel('Velocity (m/s)')
            plt.title('Underlying Dynamics')
            plt.show()
            #print('Iter {:04d} | Loss {:.6f}'.format(itr, loss.item()))
# Out:
# YYY tensor([0.])
# YYY tensor([4.8058e-06])
# YYY tensor([9.6116e-05])
# YYY tensor([0.0001])
# YYY tensor([0.0004])
# YYY tensor([0.0004])
# YYY tensor([0.0005])
# YYY tensor([0.0005])
# YYY tensor([0.0008])
# YYY tensor([0.0009])
# YYY tensor([0.0016])
# YYY tensor([0.0017])
# YYY tensor([0.0019])
# YYY tensor([0.0019])
# YYY tensor([0.0027])
# YYY tensor([0.0031])
# YYY tensor([0.0052])
# YYY tensor([0.0055])
# YYY tensor([0.0060])
# YYY tensor([0.0060])
# YYY tensor([0.0078])
# YYY tensor([0.0088])
# YYY tensor([0.0135])
# YYY tensor([0.0143])
# YYY tensor([0.0153])
# YYY tensor([0.0153])
# YYY tensor([0.0340])
# YYY tensor([0.0433])
# YYY tensor([0.0893])
# YYY tensor([0.0975])
# YYY tensor([0.1076])
# YYY tensor([0.1076])
# YYY tensor([0.1389])
# YYY tensor([0.1542])
# YYY tensor([0.2305])
# YYY tensor([0.2440])
# YYY tensor([0.2606])
# YYY tensor([0.2606])
# YYY tensor([0.3302])
# YYY tensor([0.3634])
# YYY tensor([0.5281])
# YYY tensor([0.5570])
# YYY tensor([0.5919])
# YYY tensor([0.5911])
# YYY tensor([0.6557])
# YYY tensor([0.6863])
# YYY tensor([0.8385])
# YYY tensor([0.8652])
# YYY tensor([0.8974])
# YYY tensor([0.8965])
# YYY tensor([0.9607])
# YYY tensor([0.9909])
# YYY tensor([1.1409])
# YYY tensor([1.1673])
# YYY tensor([1.1988])
# YYY tensor([1.1976])
# YYY tensor([1.2570])
# YYY tensor([1.2848])
# YYY tensor([1.4228])
# YYY tensor([1.4472])
# YYY tensor([1.4761])
# YYY tensor([1.4748])
# YYY tensor([1.5302])
# YYY tensor([1.5560])
# YYY tensor([1.6840])
# YYY tensor([1.7067])
# YYY tensor([1.7333])
# YYY tensor([1.7319])
# YYY tensor([1.7819])
# YYY tensor([1.8052])
# YYY tensor([1.9204])
# YYY tensor([1.9409])
# YYY tensor([1.9647])
# YYY tensor([1.9633])
# YYY tensor([2.0085])
# YYY tensor([2.0295])
# YYY tensor([2.1333])
# YYY tensor([2.1518])
# YYY tensor([2.1732])
# YYY tensor([2.1717])
# YYY tensor([2.2119])
# YYY tensor([2.2303])
# YYY tensor([2.3220])
# YYY tensor([2.3385])
# YYY tensor([2.3573])
# YYY tensor([2.3558])
# YYY tensor([2.3915])
# YYY tensor([2.4078])
# YYY tensor([2.4888])
# YYY tensor([2.5034])
# YYY tensor([2.5200])
# YYY tensor([2.5185])
# YYY tensor([2.5496])
# YYY tensor([2.5638])
# YYY tensor([2.6342])
# YYY tensor([2.6469])
# YYY tensor([2.6612])
# YYY tensor([2.6599])
# YYY tensor([2.6869])
# YYY tensor([2.6992])
# YYY tensor([2.7603])
# YYY tensor([2.7714])
# YYY tensor([2.7837])
# YYY tensor([2.7824])
# YYY tensor([2.8058])
# YYY tensor([2.8164])
# YYY tensor([2.8690])
# YYY tensor([2.8786])
# YYY tensor([2.8891])
# YYY tensor([2.8879])
# YYY tensor([2.9077])
# YYY tensor([2.9167])
# YYY tensor([2.9610])
# YYY tensor([2.9692])
# YYY tensor([2.9781])
# YYY tensor([2.9769])
# YYY tensor([2.9938])
# YYY tensor([3.0013])
# YYY tensor([3.0388])
# YYY tensor([3.0457])
# YYY tensor([3.0532])
# YYY tensor([3.0521])
# YYY tensor([3.0662])
# YYY tensor([3.0724])
# YYY tensor([3.1034])
# YYY tensor([3.1092])
# YYY tensor([3.1154])
# YYY tensor([3.1144])
# YYY tensor([3.1260])
# YYY tensor([3.1312])
# YYY tensor([3.1568])
# YYY tensor([3.1616])
# YYY tensor([3.1667])
# YYY tensor([3.1658])
# YYY tensor([3.1753])
# YYY tensor([3.1795])
# YYY tensor([3.2003])
# YYY tensor([3.2043])
# YYY tensor([3.2084])
# YYY tensor([3.2076])
# YYY tensor([3.2153])
# YYY tensor([3.2186])
# YYY tensor([3.2354])
# YYY tensor([3.2387])
# YYY tensor([3.2419])
# YYY tensor([3.2412])
# YYY tensor([3.2473])
# YYY tensor([3.2500])
# YYY tensor([3.2633])
# YYY tensor([3.2659])
# YYY tensor([3.2684])
# YYY tensor([3.2678])
# YYY tensor([3.2726])
# YYY tensor([3.2747])
# YYY tensor([3.2852])
# YYY tensor([3.2872])
# YYY tensor([3.2892])
# YYY tensor([3.2886])
# YYY tensor([3.2924])
# YYY tensor([3.2940])
# YYY tensor([3.3020])
# YYY tensor([3.3036])
# YYY tensor([3.3051])
# YYY tensor([3.3046])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# YYY tensor([0.])
# YYY tensor([0.3333])
# YYY tensor([0.6667])
# YYY tensor([1.])
# YYY tensor([1.3333])
# YYY tensor([1.6667])
# YYY tensor([2.])
# YYY tensor([2.3333])
# YYY tensor([2.6667])
# YYY tensor([3.])
# YYY tensor([3.3333])
# YYY tensor([3.6667])
# YYY tensor([4.])
# YYY tensor([4.3333])
# YYY tensor([4.6667])
# YYY tensor([5.])
# YYY tensor([5.3333])
# YYY tensor([5.6667])
# YYY tensor([6.])
# YYY tensor([6.3333])
# YYY tensor([6.6667])
# YYY tensor([7.])
# YYY tensor([7.3333])
# YYY tensor([7.6667])
# YYY tensor([8.])
# YYY tensor([8.3333])
# YYY tensor([8.6667])
# C:\Users\matthew\Miniconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# YYY tensor([0.])
# YYY tensor([4.8058e-06], grad_fn=<AddBackward0>)
# YYY tensor([9
# YYY tensor([1.0203], grad_fn=<AddBackward0>)
# YYY tensor([1.0192], grad_fn=<AddBackward0>)
# YYY tensor([1.0791], grad_fn=<AddBackward0>)
# YYY tensor([1.1073], grad_fn=<AddBackward0>)
# YYY tensor([1.2468], grad_fn=<AddBackward0>)
# YYY tensor([1.2714], grad_fn=<AddBackward0>)
# YYY tensor([1.3007], grad_fn=<AddBackward0>)
# YYY tensor([1.2995], grad_fn=<AddBackward0>)
# YYY tensor([1.3546], grad_fn=<AddBackward0>)
# YYY tensor([1.3804], grad_fn=<AddBackward0>)
# YYY tensor([1.5083], grad_fn=<AddBackward0>)
# YYY tensor([1.5309], grad_fn=<AddBackward0>)
# YYY tensor([1.5576], grad_fn=<AddBackward0>)
# YYY tensor([1.5563], grad_fn=<AddBackward0>)
# YYY tensor([1.6067], grad_fn=<AddBackward0>)
# YYY tensor([1.6302], grad_fn=<AddBackward0>)
# YYY tensor([1.7467], grad_fn=<AddBackward0>)
# YYY tensor([1.7674], grad_fn=<AddBackward0>)
# YYY tensor([1.7915], grad_fn=<AddBackward0>)
# YYY tensor([1.7902], grad_fn=<AddBackward0>)
# YYY tensor([1.8362], grad_fn=<AddBackward0>)
# YYY tensor([1.8575], grad_fn=<AddBackward0>)
# YYY tensor([1.9631], grad_fn=<AddBackward0>)
# YYY tensor([1.9819], grad_fn=<AddBackward0>)
# YYY tensor([2.0037], grad_fn=<AddBackward0>)
# YYY tensor([2.0024], grad_fn=<AddBackward0>)
# YYY tensor([0.])
# YYY tensor([4.8461e-06], grad_fn=<AddBackward0>)
# YYY tensor([9.6922e-05], grad_fn=<AddBackward0>)
# YYY tensor([0.0001], grad_fn=<AddBackward0>)
# YYY tensor([0.0004], grad_fn=<AddBackward0>)
# YYY tensor([0.0004], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0008], grad_fn=<AddBackward0>)
# YYY tensor([0.0010], grad_fn=<AddBackward0>)
# YYY tensor([0.0017], grad_fn=<AddBackward0>)
# YYY tensor([0.0019], grad_fn=<AddBackward0>)
# YYY tensor([0.0020], grad_fn=<AddBackward0>)
# YYY tensor([0.0020], grad_fn=<AddBackward0>)
# YYY tensor([0.0029], grad_fn=<AddBackward0>)
# YYY tensor([0.0033], grad_fn=<AddBackward0>)
# YYY tensor([0.0053], grad_fn=<AddBackward0>)
# YYY tensor([0.0057], grad_fn=<AddBackward0>)
# YYY tensor([0.0062], grad_fn=<AddBackward0>)
# YYY tensor([0.0062], grad_fn=<AddBackward0>)
# YYY tensor([0.0081], grad_fn=<AddBackward0>)
# YYY tensor([0.0090], grad_fn=<AddBackward0>)
# YYY tensor([0.0137], grad_fn=<AddBackward0>)
# YYY tensor([0.0146], grad_fn=<AddBackward0>)
# YYY tensor([0.0156], grad_fn=<AddBackward0>)
# YYY tensor([0.0156], grad_fn=<AddBackward0>)
# YYY tensor([0.0190], grad_fn=<AddBackward0>)
# YYY tensor([0.0207], grad_fn=<AddBackward0>)
# YYY tensor([0.0290], grad_fn=<AddBackward0>)
# YYY tensor([0.0305], grad_fn=<AddBackward0>)
# YYY tensor([0.0323], grad_fn=<AddBackward0>)
# YYY tensor([0.0323], grad_fn=<AddBackward0>)
# YYY tensor([0.0405], grad_fn=<AddBackward0>)
# YYY tensor([0.0445], grad_fn=<AddBackward0>)
# YYY tensor([0.0647], grad_fn=<AddBackward0>)
# YYY tensor([0.0683], grad_fn=<AddBackward0>)
# YYY tensor([0.0727], grad_fn=<AddBackward0>)
grad_fn=<AddBackward0>)
# YYY tensor([0.0019], grad_fn=<AddBackward0>)
# YYY tensor([0.0019], grad_fn=<AddBackward0>)
# YYY tensor([0.0026], grad_fn=<AddBackward0>)
# YYY tensor([0.0029], grad_fn=<AddBackward0>)
# YYY tensor([0.0047], grad_fn=<AddBackward0>)
# YYY tensor([0.0050], grad_fn=<AddBackward0>)
# YYY tensor([0.0053], grad_fn=<AddBackward0>)
# YYY tensor([0.0053], grad_fn=<AddBackward0>)
# YYY tensor([0.0074], grad_fn=<AddBackward0>)
# YYY tensor([0.0084], grad_fn=<AddBackward0>)
# YYY tensor([0.0136], grad_fn=<AddBackward0>)
# YYY tensor([0.0145], grad_fn=<AddBackward0>)
# YYY tensor([0.0156], grad_fn=<AddBackward0>)
# YYY tensor([0.0156], grad_fn=<AddBackward0>)
# YYY tensor([0.0198], grad_fn=<AddBackward0>)
# YYY tensor([0.0219], grad_fn=<AddBackward0>)
# YYY tensor([0.0323], grad_fn=<AddBackward0>)
# YYY tensor([0.0342], grad_fn=<AddBackward0>)
# YYY tensor([0.0365], grad_fn=<AddBackward0>)
# YYY tensor([0.0365], grad_fn=<AddBackward0>)
# YYY tensor([0.0430], grad_fn=<AddBackward0>)
# YYY tensor([0.0462], grad_fn=<AddBackward0>)
# YYY tensor([0.0624], grad_fn=<AddBackward0>)
# YYY tensor([0.0653], grad_fn=<AddBackward0>)
# YYY tensor([0.0688], grad_fn=<AddBackward0>)
# YYY tensor([0.0688], grad_fn=<AddBackward0>)
# YYY tensor([0.0823], grad_fn=<AddBackward0>)
# YYY tensor([0.0890], grad_fn=<AddBackward0>)
# YYY tensor([0.1223], grad_fn=<AddBackward0>)
# YYY tensor([0.1282], grad_fn=<AddBackward0>)
# YYY tensor([0.1356], grad_fn=<AddBackward0>)
# YYY tensor([0.1356], grad_fn=<AddBackward0>)
# YYY tensor([0.1628], grad_fn=<AddBackward0>)
# YYY tensor([0.1761], grad_fn=<AddBackward0>)
# YYY tensor([0.2427], grad_fn=<AddBackward0>)
# ...
# YYY tensor([1.6552], grad_fn=<AddBackward0>)
# YYY tensor([1.6987], grad_fn=<AddBackward0>)
# YYY tensor([1.7188], grad_fn=<AddBackward0>)
# YYY tensor([1.8187], grad_fn=<AddBackward0>)
# YYY tensor([1.8364], grad_fn=<AddBackward0>)
# YYY tensor([1.8571], grad_fn=<AddBackward0>)
# YYY tensor([1.8558], grad_fn=<AddBackward0>)
# YYY tensor([1.8950], grad_fn=<AddBackward0>)
# YYY tensor([1.9131], grad_fn=<AddBackward0>)
# YYY tensor([2.0029], grad_fn=<AddBackward0>)
# YYY tensor([2.0189], grad_fn=<AddBackward0>)
# YYY tensor([2.0374], grad_fn=<AddBackward0>)
# YYY tensor([2.0361], grad_fn=<AddBackward0>)
# YYY tensor([0.])
# YYY tensor([5.6151e-06], grad_fn=<AddBackward0>)
# YYY tensor([0.0001], grad_fn=<AddBackward0>)
# YYY tensor([0.0002], grad_fn=<AddBackward0>)
# YYY tensor([0.0004], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0010], grad_fn=<AddBackward0>)
# YYY tensor([0.0012], grad_fn=<AddBackward0>)
# YYY tensor([0.0022], grad_fn=<AddBackward0>)
# YYY tensor([0.
# YYY tensor([1.2154], grad_fn=<AddBackward0>)
# YYY tensor([1.2671], grad_fn=<AddBackward0>)
# YYY tensor([1.2913], grad_fn=<AddBackward0>)
# YYY tensor([1.4112], grad_fn=<AddBackward0>)
# YYY tensor([1.4325], grad_fn=<AddBackward0>)
# YYY tensor([1.4575], grad_fn=<AddBackward0>)
# YYY tensor([1.4563], grad_fn=<AddBackward0>)
# YYY tensor([1.5039], grad_fn=<AddBackward0>)
# YYY tensor([1.5260], grad_fn=<AddBackward0>)
# YYY tensor([1.6359], grad_fn=<AddBackward0>)
# YYY tensor([1.6554], grad_fn=<AddBackward0>)
# YYY tensor([1.6782], grad_fn=<AddBackward0>)
# YYY tensor([1.6769], grad_fn=<AddBackward0>)
# YYY tensor([1.7204], grad_fn=<AddBackward0>)
# YYY tensor([1.7405], grad_fn=<AddBackward0>)
# YYY tensor([1.8402], grad_fn=<AddBackward0>)
# YYY tensor([1.8580], grad_fn=<AddBackward0>)
# YYY tensor([1.8786], grad_fn=<AddBackward0>)
# YYY tensor([1.8772], grad_fn=<AddBackward0>)
# YYY tensor([1.9159], grad_fn=<AddBackward0>)
# YYY tensor([1.9337], grad_fn=<AddBackward0>)
# YYY tensor([2.0221], grad_fn=<AddBackward0>)
# YYY tensor([2.0379], grad_fn=<AddBackward0>)
# YYY tensor([2.0561], grad_fn=<AddBackward0>)
# YYY tensor([2.0548], grad_fn=<AddBackward0>)
# YYY tensor([0.])
# YYY tensor([5.6495e-06], grad_fn=<AddBackward0>)
# YYY tensor([0.0001], grad_fn=<AddBackward0>)
# YYY tensor([0.0002], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0010], grad_fn=<AddBackward0>)
# YYY tensor([0.0012], grad_fn=<AddBackward0>)
# YYY tensor([0.0022], grad_fn=<AddBackward0>)
# YYY tensor([0.0024], grad_fn=<AddBackward0>)
# YYY tensor([0.0026], grad_fn=<AddBackward0>)
# YYY tensor([0.0026], grad_fn=<AddBackward0>)
# YYY tensor([0.0039], grad_fn=<AddBackward0>)
# YYY tensor([0.0045], grad_fn=<AddBackward0>)
# YYY tensor([0.0075], grad_fn=<AddBackward0>)
# YYY tensor([0.0080], grad_fn=<AddBackward0>)
# YYY tensor([0.0087], grad_fn=<AddBackward0>)
# YYY tensor([0.0087], grad_fn=<AddBackward0>)
# YYY tensor([0.0112], grad_fn=<AddBackward0>)
# YYY tensor([0.0124], grad_fn=<AddBackward0>)
# YYY tensor([0.0187], grad_fn=<AddBackward0>)
# YYY tensor([0.0198], grad_fn=<AddBackward0>)
# YYY tensor([0.0212], grad_fn=<AddBackward0>)
# YYY tensor([0.0212], grad_fn=<AddBackward0>)
# YYY tensor([0.0460], grad_fn=<AddBackward0>)
# YYY tensor([0.0583], grad_fn=<AddBackward0>)
# YYY tensor([0.1192], grad_fn=<AddBackward0>)
# YYY tensor([0.1299], grad_fn=<AddBackward0>)
# YYY tensor([0.1433], grad_fn=<AddBackward0>)
# YYY tensor([0.1432], grad_fn=<AddBackward0>)
# YYY tensor([0.1931], grad_fn=<AddBackward0>)
# YYY tensor([0.2171], grad_fn=<AddBackward0>)
# YYY tensor([0.3364], grad_fn=<AddBackward0>)
# YYY tensor([0.3574], grad_fn=<AddBackward0>)
# YYY tensor([0.3830], grad_fn=<AddBackward0>)
# YYY tensor([0.3827], grad_fn=<AddBackward0>)
# YYY tensor([0.4415], grad_fn=<AddBackward0>)
# YYY tensor([0.4696], grad_fn=<AddBackward0>)
# YYY tensor([0.6087], grad_fn=<AddBackward0>)
# YYY tensor([0.6332], grad_fn=<AddBackward0>)
# YYY tensor([0.6627], grad_fn=<AddBackward0>)
# YYY tensor([0.6620], grad_fn=<AddBackward0>)
# YYY tensor([0.7227], grad_fn=<AddBackward0>)
# YYY tensor([0.7514], grad_fn=<AddBackward0>)
# YYY tensor([0.8936], grad_fn=<AddBackward0>)
# YYY tensor([0.9187], grad_fn=<AddBackward0>)
# YYY tensor([0.9486], grad_fn=<AddBackward0>)
# YYY tensor([0.9476], grad_fn=<AddBackward0>)
# YYY tensor([1.0044], grad_fn=<AddBackward0>)
# YYY tensor([1.0311], grad_fn=<AddBackward0>)
# YYY tensor([1.1635], grad_fn=<AddBackward0>)
# YYY tensor([1.1869], grad_fn=<AddBackward0>)
# YYY tensor([1.2146], grad_fn=<AddBackward0>)
# YYY tensor([1.2135], grad_fn=<AddBackward0>)
# YYY tensor([1.2660], grad_fn=<AddBackward0>)
# YYY tensor([1.2905], grad_fn=<AddBackward0>)
# YYY tensor([1.4123], grad_fn=<AddBackward0>)
# YYY tensor([1.4338], grad_fn=<AddBackward0>)
# YYY tensor([1.4592], grad_fn=<AddBackward0>)
# YYY tensor([1.4580], grad_fn=<AddBackward0>)
# YYY tensor([1.5064], grad_fn=<AddBackward0>)
# YYY tensor([1.5289], grad_fn=<AddBackward0>)
# YYY tensor([1.6406], grad_fn=<AddBackward0>)
# YYY tensor([1.6605], grad_fn=<AddBackward0>)
# YYY tensor([1.6836], grad_fn=<AddBackward0>)
# YYY tensor([1.6824], grad_fn=<AddBackward0>)
# YYY tensor([1.7262], grad_fn=<AddBackward0>)
# YYY tensor([1.7465], grad_fn=<AddBackward0>)
# YYY tensor([1.8473], grad_fn=<AddBackward0>)
# YYY tensor([1.8653], grad_fn=<AddBackward0>)
# YYY tensor([1.8861], grad_fn=<AddBackward0>)
# YYY tensor([1.8848], grad_fn=<AddBackward0>)
# YYY tensor([1.9242], grad_fn=<AddBackward0>)
# YYY tensor([1.9424], grad_fn=<AddBackward0>)
# YYY tensor([2.0327], grad_fn=<AddBackward0>)
# YYY tensor([2.0488], grad_fn=<AddBackward0>)
# YYY tensor([2.0674], grad_fn=<AddBackward0>)
# YYY tensor([2.0660], grad_fn=<AddBackward0>)
# YYY tensor([0.])
# YYY tensor([5.6559e-06], grad_fn=<AddBackward0>)
# YYY tensor([0.0001], grad_fn=<AddBackward0>)
# YYY tensor([0.0002], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0009], grad_fn=<AddBackward0>)
# YYY tensor([0.0011], grad_fn=<AddBackward0>)
# YYY tensor([0.0020], grad_fn=<AddBackward0>)
# YYY tensor([0.0022], grad_fn=<AddBackward0>)
# YYY tensor([0.
# YYY tensor([1.3681], grad_fn=<AddBackward0>)
# YYY tensor([1.3902], grad_fn=<AddBackward0>)
# YYY tensor([1.4163], grad_fn=<AddBackward0>)
# YYY tensor([1.4151], grad_fn=<AddBackward0>)
# YYY tensor([1.4644], grad_fn=<AddBackward0>)
# YYY tensor([1.4873], grad_fn=<AddBackward0>)
# YYY tensor([1.6012], grad_fn=<AddBackward0>)
# YYY tensor([1.6214], grad_fn=<AddBackward0>)
# YYY tensor([1.6450], grad_fn=<AddBackward0>)
# YYY tensor([1.6438], grad_fn=<AddBackward0>)
# YYY tensor([1.6885], grad_fn=<AddBackward0>)
# YYY tensor([1.7093], grad_fn=<AddBackward0>)
# YYY tensor([1.8123], grad_fn=<AddBackward0>)
# YYY tensor([1.8306], grad_fn=<AddBackward0>)
# YYY tensor([1.8519], grad_fn=<AddBackward0>)
# YYY tensor([1.8506], grad_fn=<AddBackward0>)
# YYY tensor([1.8908], grad_fn=<AddBackward0>)
# YYY tensor([1.9094], grad_fn=<AddBackward0>)
# YYY tensor([2.0015], grad_fn=<AddBackward0>)
# YYY tensor([2.0179], grad_fn=<AddBackward0>)
# YYY tensor([2.0369], grad_fn=<AddBackward0>)
# YYY tensor([2.0356], grad_fn=<AddBackward0>)
# YYY tensor([0.])
# YYY tensor([5.6402e-06], grad_fn=<AddBackward0>)
# YYY tensor([0.0001], grad_fn=<AddBackward0>)
# YYY tensor([0.0002], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0005], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0006], grad_fn=<AddBackward0>)
# YYY tensor([0.0010], grad_fn=<AddBackward0>)
# YYY tensor([0.0012], grad_fn=<AddBackward0>)
# YYY tensor([0.0022], grad_fn=<AddBackward0>)
# YYY tensor([0.0024], grad_fn=<AddBackward0>)
# YYY tensor([0.0026], grad_fn=<AddBackward0>)
# YYY tensor([0.0026], grad_fn=<AddBackward0>)
# YYY tensor([0.0039], grad_fn=<AddBackward0>)
# YYY tensor([0.0045], grad_fn=<AddBackward0>)
# YYY tensor([0.0075], grad_fn=<AddBackward0>)
# YYY tensor([0.0080], grad_fn=<AddBackward0>)
# YYY tensor([0.0087], grad_fn=<AddBackward0>)
# YYY tensor([0.0087], grad_fn=<AddBackward0>)
# YYY tensor([0.0207], grad_fn=<AddBackward0>)
# YYY tensor([0.0267], grad_fn=<AddBackward0>)
# YYY tensor([0.0565], grad_fn=<AddBackward0>)
# YYY tensor([0.0618], grad_fn=<AddBackward0>)
# YYY tensor([0.0684], grad_fn=<AddBackward0>)
# YYY tensor([0.0684], grad_fn=<AddBackward0>)
# YYY tensor([0.0931], grad_fn=<AddBackward0>)
# YYY tensor([0.1052], grad_fn=<AddBackward0>)
# YYY tensor([0.1657], grad_fn=<AddBackward0>)
# YYY tensor([0.1763], grad_fn=<AddBackward0>)
# YYY tensor([0.1896], grad_fn=<AddBackward0>)
# YYY tensor([0.1895], grad_fn=<AddBackward0>)
# YYY tensor([0.2416], grad_fn=<AddBackward0>)
# YYY tensor([0.2667], grad_fn=<AddBackward0>)
# YYY tensor([0.3910], grad_fn=<AddBackward0>)
# YYY tensor([0.4128], grad_fn=<AddBackward0>)
# YYY tensor([0.4395], grad_fn=<AddBackward0>)
# YYY tensor([0.4391], grad_fn=<AddBackward0>)
# YYY tensor([0.4992], grad_fn=<AddBackward0>)
# YYY tensor([0.5277], grad_fn=<AddBackward0>)
# YYY tensor([0.6694], grad_fn=<AddBackward0>)
# YYY tensor([0.6943], grad_fn=<AddBackward0>)
# YYY tensor([0.7243], grad_fn=<AddBackward0>)
# YYY tensor([0.7234], grad_fn=<AddBackward0>)
# YYY tensor([0.7819], grad_fn=<AddBackward0>)
# YYY tensor([0.8095], grad_fn=<AddBackward0>)
# YYY tensor([0.9463], grad_fn=<AddBackward0>)
# YYY tensor([0.9704], grad_fn=<AddBackward0>)
# YYY tensor([0.9991], grad_fn=<AddBackward0>)
# YYY tensor([0.9981], grad_fn=<AddBackward0>)
# YYY tensor([1.0535], grad_fn=<AddBackward0>)
# YYY tensor([1.0795], grad_fn=<AddBackward0>)
# YYY tensor([1.2085], grad_fn=<AddBackward0>)
# YYY tensor([1.2313], grad_fn=<AddBackward0>)
# YYY tensor([1.2582], grad_fn=<AddBackward0>)
# YYY tensor([1.2571], grad_fn=<AddBackward0>)
# YYY tensor([1.3084], grad_fn=<AddBackward0>)
# YYY tensor([1.3323], grad_fn=<AddBackward0>)
# YYY tensor([1.4511], grad_fn=<AddBackward0>)
# YYY tensor([1.4721], grad_fn=<AddBackward0>)
# YYY tensor([1.4968], grad_fn=<AddBackward0>)
# YYY tensor([1.4956], grad_fn=<AddBackward0>)
# YYY tensor([1.5423], grad_fn=<AddBackward0>)
# YYY tensor([1.5640], grad_fn=<AddBackward0>)
# YYY tensor([1.6717], grad_fn=<AddBackward0>)
# YYY tensor([1.6908], grad_fn=<AddBackward0>)
# YYY tensor([1.7131], grad_fn=<AddBackward0>)
# YYY tensor([1.7118], grad_fn=<AddBackward0>)
# YYY tensor([1.7536], grad_fn=<AddBackward0>)
# YYY tensor([1.7730], grad_fn=<AddBackward0>)
# YYY tensor([1.8690], grad_fn=<AddBackward0>)
# YYY tensor([1.8861], grad_fn=<AddBackward0>)
# YYY tensor([1.9059], grad_fn=<AddBackward0>)
# YYY tensor([1.9046], grad_fn=<AddBackward0>)
# YYY tensor([1.9422], grad_fn=<AddBackward0>)
# YYY tensor([1.9596], grad_fn=<AddBackward0>)
# YYY tensor([2.0455], grad_fn=<AddBackward0>)
# YYY tensor([2.0609], grad_fn=<AddBackward0>)
# YYY tensor([2.0786], grad_fn=<AddBackward0>)
# YYY tensor([2.0773], grad_fn=<AddBackward0>)

# %% [markdown]
# ###  Question 4: Try swapping odeint_nn with odeint_adjoint and retraining the model. Is there a change in runtime or number of iterations before convergence? Why do you think we are seeing these differences between the two methods?
#
# A: I was not able to get my model to produce meaningful results. But I suspect that the runtime for the adjoint method would be slower while using constant memory.
#
# ### Question 5: Why might this example be a bad problem to solve with the adjoint method?
# A: We are modeling a simple deterministic system.
